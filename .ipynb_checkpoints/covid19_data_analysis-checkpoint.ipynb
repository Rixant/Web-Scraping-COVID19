# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup as bs
print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
URL = 'https://www.worldometers.info/coronavirus/'
page = requests.get(URL)
soup = bs(page.content, 'html.parser')
##print(soup)

# %%
results = soup.find(id='main_table_countries_today')
##print(results.prettify())

# %%
headings = []
th_headings = results.find_all("th")
for th_heading in th_headings:
    th_heading = (th_heading.text).strip("\n")
    headings.append(th_heading)
print(headings)
# Out:
# ['#', 'Country,Other', 'TotalCases', 'NewCases', 'TotalDeaths', 'NewDeaths', 'TotalRecovered', 'NewRecovered', 'ActiveCases', 'Serious,Critical', 'Tot\xa0Cases/1M pop', 'Deaths/1M pop', 'TotalTests', 'Tests/\n1M pop', 'Population', 'Continent', '1 Caseevery X ppl', '1 Deathevery X ppl', '1 Testevery X ppl']

# %%
newDataFrame = []

for row in results.find_all('tr'):
    rows = []
    
    for cell in row.find_all('td'):
        rows.append((cell.text).strip("\n"))
    
    if(len(rows)> 0):
        data = {
                headings[0]: rows[0],
                headings[1]: rows[1],
                headings[2]: rows[2],
                headings[3]: rows[3],
                headings[4]: rows[4],
                headings[5]: rows[5],
                headings[6]: rows[6],
                headings[7]: rows[7],
                headings[8]: rows[8],
                headings[9]: rows[9],
                headings[10]: rows[10],            
        }
        
        newDataFrame.append(data)

# %%
df =pd.DataFrame(newDataFrame)
print(df.head(1))
# Out:
#      #  Country,Other  TotalCases NewCases TotalDeaths NewDeaths  \
# 0       North America  25,933,086  +16,935     552,109    +1,144
# 1                Asia  21,402,284     +759     347,528       +25
# 2       South America  13,908,737   +1,644     375,705       +23
# 3              Europe  25,748,035              586,193
# 4              Africa   3,037,007               72,216
# 5             Oceania      48,987      +43       1,067
# 6                             721                   15
# 7               World  90,078,857  +19,381   1,934,833    +1,192
# 8    1            USA  22,699,938             381,480
# 9    2          India  10,451,346             151,048
# 10   3         Brazil   8,075,998             202,657
# 11   4         Russia   3,379,103              61,381
# 12   5             UK   3,017,409              80,868
# 13   6         France   2,767,312              67,599
# 14   7         Turkey   2,317,118              22,631
# ...

# %%
df.replace(' ', np.nan)
print(df.head(50))
# Out:
#      #  Country,Other  TotalCases NewCases TotalDeaths NewDeaths  \
# 0       North America  25,931,700  +16,105     552,089    +1,135
# 1                Asia  21,402,259     +734     347,528       +25
# 2       South America  13,908,737   +1,644     375,705       +23
# 3              Europe  25,748,035              586,193
# 4              Africa   3,037,007               72,216
# 5             Oceania      48,987      +43       1,067
# 6                             721                   15
# 7               World  90,077,446  +18,526   1,934,813    +1,183
# 8    1            USA  22,699,938             381,480
# 9    2          India  10,451,346             151,048
# 10   3         Brazil   8,075,998             202,657
# 11   4         Russia   3,379,103              61,381
# 12   5             UK   3,017,409              80,868
# 13   6         France   2,767,312              67,599
# 14   7         Turkey   2,317,118              22,631
# ...

# %%
df.dtypes
# Out:
# #                   object
# Country,Other       object
# TotalCases          object
# NewCases            object
# TotalDeaths         object
# NewDeaths           object
# TotalRecovered      object
# NewRecovered        object
# ActiveCases         object
# Serious,Critical    object
# Tot Cases/1M pop    object
# dtype: object

# %%
df = df.rename(columns={"#": "Index", "Country,Other": "Countries", "Serious,Critical":"CriticalCases", "Tot\xa0Cases/1M pop":"TotalCasesPer1M"},inplace = True)

# %%
df.drop(df.index[[0,1,2,3,4,5,6,7]])
# Out:
#     Index Countries  TotalCases NewCases TotalDeaths NewDeaths TotalRecovered  \
# 8       1       USA  22,699,938             381,480                13,393,078
# 9       2     India  10,451,346             151,048                10,075,395
# 10      3    Brazil   8,075,998             202,657                 7,144,011
# 11      4    Russia   3,379,103              61,381                 2,754,809
# 12      5        UK   3,017,409              80,868                 1,406,967
# ..    ...       ...         ...      ...         ...       ...            ...
# 231          Total:  25,748,035              586,193               13,808,653
# 232          Total:   3,037,007               72,216                2,461,292
# 233          Total:      48,987      +43       1,067                   33,643
# 234          Total:         721                   15                      706
# 235          Total:  90,077,446  +18,526   1,934,813    +1,183     64,463,359
#
# ...
